# %%
import json

with open('F:\PBL7\AI-Healthcare\\app\Data\intents_short.json', 'r') as f:
    intents = json.load(f)
    
intents
# Out:
# {'intents': [{'tag': 'abdominal_pain',
#    'patterns': ['abdominal pain',
#     'abdomen hurts',
#     'pain in stomach',
#     'pain in abdomen']},
#   {'tag': 'anxiety', 'patterns': ['suffer from anxeity']},
#   {'tag': 'abnormal_menstruation',
#    'patterns': ['abnormal menstruation',
#     'heavy period',
#     'Heavy flow',
#     'Period lasts longer',
#     'period painful',
#     'strong menstrual pain',
#     'Menstrual cramps strong']},
#   {'tag': 'acidity',
#    'patterns': ['acid reflux', 'acidity problems', 'heartburn']},
#   {'tag': 'acute_liver_failure',
#    'patterns': ['acute liver failure',
#     'liver hurts',
#     'pain around liver',
#     'Upper right abdomen hurts']},
#   {'tag': 'altered_sensorium',
#    'patterns': ['altered sensorium',
#     "can't think clearly",
#     'hard to think',
#     'unable to concentrate']},
#   {'tag': 'anxiety',
#    'patterns': ['anxiety', 'anxious', 'really worried', 'nervous']},
#   {'tag': 'back_pain',
#    'patterns': ['back hurts', 'back pain', 'pain in back']},
#   {'tag': 'belly_pain',
#    'patterns': ['belly hurts',
#     'belly pain',
#     'pain in belly',
#     'Stomach hurts',
#     'Stomach pain']},
#   {'tag': 'blackheads',
#    'patterns': ['blackheads',
#     'lot of blackheads',
#     'Blackheads on face',
#     'Blackheads on body']},
#   {'tag': 'bladder_discomfort',
#    'patterns': ['bladder discomfort',
#     'bladder hurts',
#     'discomfort in bladder',
#     'Pressure in bladder']},
#   {'tag': 'blister',
#    'patterns': ['blisters',
#     'arms are blistered',
#     'feet are blistered',
#     'Body is blistered']},
#   {'tag': 'blood_in_sputum',
#    'patterns': ['blood in sputum',
#     'coughing up blood',
#     'Blood while caughing']},
#   {'tag': 'bloody_stool',
#    'patterns': ['blood in stool', 'pooped out blood', 'bloody stool']},
#   {'tag': 'blurred_and_distorted_vision',
#    'patterns': ['blurred and distorted vision',
#     "can't see clearly",
#     "can't see",
#     'blurry vision',
#     'Vision distorted']},
#   {'tag': 'breathlessness',
#    'patterns': ['breathlessness',
#     'difficulty breathing',
#     'out of breath',
#     'feel winded',
#     'Short of breath']},
#   {'tag': 'brittle_nails',
#    'patterns': ['brittle nails',
#     'nails weak',
#     'Nails brittle',
#     'Nails easily broken']},
#   {'tag': 'bruising',
#    'patterns': ['bruising', 'bruises', 'easily bruised', 'lot of bruises']},
#   {'tag': 'burning_micturition',
#    'patterns': ['burning micturition',
#     'hurts when pee',
#     'burns when pee',
#     'Burning sensation peeing']},
#   {'tag': 'chest_pain',
#    'patterns': ['chest hurts', 'chest pain', 'pain in chest']},
#   {'tag': 'chills', 'patterns': ['chills', 'cold']},
#   {'tag': 'cold_hands_and_feets',
#    'patterns': ['cold hands and feets',
#     'hands are cold',
#     'feet are cold',
#     'cold hands',
#     'cold feet']},
#   {'tag': 'coma', 'patterns': ['coma', 'experienced coma', 'was in coma']},
#   {'tag': 'constipation',
#    'patterns': ["can't poop",
#     'constipated',
#     'am constipated',
#     "haven't pooped in a while"]},
#   {'tag': 'continuous_feel_of_urine',
#    'patterns': ['continuous feel of urine',
#     'have to pee',
#     'Urge to pee',
#     'pee constantly']},
#   {'tag': 'continuous_sneezing',
#    'patterns': ['continuous sneezing',
#     'sneezing all the time',
#     'sneeze a lot',
#     'Always sneezing',
#     'sneeze constantly']},
#   {'tag': 'cough',
#    'patterns': ['cough',
#     'coughing all the time',
#     'cough a lot',
#     'Always caughing',
#     'cough constantly']},
#   {'tag': 'congestion',
#    'patterns': ['congestion',
#     "can't breathe",
#     'nose stuffy',
#     'nose full',
#     'nasal congestion']},
#   {'tag': 'cramps', 'patterns': ['cramps', 'cramping up']},
#   {'tag': 'dark_urine',
#    'patterns': ['urine dark', 'Darker color urine', 'pee dark']},
#   {'tag': 'dehydration',
#    'patterns': ['dehydrated', 'experiencing dehydration']},
#   {'tag': 'depression',
#    'patterns': ['depression', 'have depression', 'feel depressed']},
#   {'tag': 'diarrhoea',
#    'patterns': ['diarrhoea', 'always on toilet', 'poop often', 'poo a lot']},
#   {'tag': 'dischromic_patches',
#    'patterns': ['dischromic patches',
#     'lost color on skin',
#     'patches different color',
#     'skin patched']},
#   {'tag': 'distention_of_abdomen',
#    'patterns': ['distention of abdomen',
#     'stomach bloated',
#     'abdomen bloated',
#     'Abdomen expanded']},
#   {'tag': 'dizziness',
#    'patterns': ['dizziness',
#     'feeling dizzy',
#     'experiencing dizziness',
#     'woozy',
#     'unsteady',
#     'weak']},
#   {'tag': 'drying_and_tingling_lips',
#    'patterns': ['drying and tingling lips',
#     'lips tingly',
#     'dry lips',
#     'Dried lips',
#     'Tingling lips']},
#   {'tag': 'enlarged_thyroid',
#    'patterns': ['thyroid large', 'enlarged thyroid']},
#   {'tag': 'excessive_hunger',
#    'patterns': ['excessive hunger',
#     'really hungry',
#     'always hungry',
#     'hunger']},
#   {'tag': 'extra_marital_contacts',
#    'patterns': ['extra marital contacts', 'affair', 'sex with stranger']},
#   {'tag': 'family_history',
#    'patterns': ['family history',
#     'family disease history',
#     'parents also sick',
#     'genetically at risk',
#     'genetics']},
#   {'tag': 'fast_heart_rate',
#    'patterns': ['fast heart rate',
#     'heart beating fast',
#     'high heart rate',
#     'Heart really pumping']},
#   {'tag': 'fatigue',
#    'patterns': ['really tired', 'fatigued', 'lack energy', 'no energy']},
#   {'tag': 'fluid_overload',
#    'patterns': ['fluid overload', 'swolen', 'body swelling', 'gained weight']},
#   {'tag': 'foul_smell_ofurine',
#    'patterns': ['foul smell ofurine',
#     'urine smells bad',
#     'pee smells',
#     'pee stinks']},
#   {'tag': 'headache',
#    'patterns': ['headache', 'have headache', 'head hurts', 'pain in head']},
#   {'tag': 'high_fever',
#    'patterns': ['high fever', 'bad fever', 'really high temperature']},
#   {'tag': 'hip_joint_pain',
#    'patterns': ['hip joint pain', 'hip hurts', 'pain in hip']},
#   {'tag': 'history_of_alcohol_consumption',
#    'patterns': ['history of alcohol consumption',
#     'drink a lot',
#     'drinking for long time',
#     'History drinking']},
#   {'tag': 'increased_appetite',
#    'patterns': ['appetite', 'want to eat', 'Appetite increased']},
#   {'tag': 'indigestion',
#    'patterns': ['indigestion',
#     'discomfort in stomach',
#     'upset stomach',
#     'Upper abdomen pain']},
#   {'tag': 'inflammatory_nails',
#    'patterns': ['inflammatory nails',
#     'nails inflamed',
#     'nails infected',
#     'Inflammation around nails']},
#   {'tag': 'internal_itching',
#    'patterns': ['itching on inside', 'internal itching', 'itches inside']},
#   {'tag': 'irregular_sugar_level',
#    'patterns': ['irregular sugar level',
#     'sugar level off',
#     'Sugar level not normal',
#     'low sugar',
#     'high sugar']},
#   {'tag': 'irritability',
#    'patterns': ['irritability',
#     'easily irritable',
#     'annoyed',
#     'Easily frustrated']},
#   {'tag': 'irritation_in_anus',
#    'patterns': ['irritation in anus',
#     'butt itchy',
#     'Anus itchy',
#     'irritated anus']},
#   {'tag': 'itching',
#    'patterns': ['itching', 'itchy everywhere', 'body itching']},
#   {'tag': 'joint_pain',
#    'patterns': ['joints hurt',
#     'ankles hurt',
#     'Pain joints',
#     'Pain arm joints']},
#   {'tag': 'knee_pain', 'patterns': ['knees hurt', 'Pain in knee']},
#   {'tag': 'lack_of_concentration',
#    'patterns': ['lack of concentration',
#     "can't concentrate",
#     'lack concentration',
#     "Can't focus"]},
#   {'tag': 'lethargy',
#    'patterns': ['lethargy',
#     'lack energy',
#     'enthusiasm low',
#     'sleepy',
#     'sluggy']},
#   {'tag': 'loss_of_appetite',
#    'patterns': ["can't eat",
#     "don't have appetite",
#     'lost appetite',
#     'loss of appetite']},
#   {'tag': 'loss_of_balance',
#    'patterns': ['loss of balance',
#     'losing balance',
#     'unsteady',
#     'dizzy',
#     'vertigo']},
#   {'tag': 'loss_of_smell',
#    'patterns': ["can't smell anything",
#     "don't feel sense smell",
#     'no smell',
#     'no sense of smell']},
#   {'tag': 'malaise',
#    'patterns': ["don't feel well",
#     "don't feel good",
#     'not comfortable',
#     'Everything hurts']},
#   {'tag': 'mild_fever',
#    'patterns': ['fever',
#     'small fever',
#     'little fevered',
#     'highered temperature']},
#   {'tag': 'mood_swings',
#    'patterns': ['changes in mood', 'mood swings', 'Mood changes often']},
#   {'tag': 'movement_stiffness',
#    'patterns': ['slow',
#     "can't move normally",
#     'muscles stiff',
#     'move stiffly']},
#   {'tag': 'mucoid_sputum',
#    'patterns': ['coughing up mucus', 'mucous sputum', 'mucous phlegm']},
#   {'tag': 'muscle_pain',
#    'patterns': ['muscles ache', 'Muscles hurt', 'pain muscles']},
#   {'tag': 'muscle_wasting',
#    'patterns': ['loosing muscle',
#     'muscle atrophy',
#     'muscles getting smaller']},
#   {'tag': 'muscle_weakness',
#    'patterns': ['muscles weak', 'weakness in muscles']},
#   {'tag': 'nausea',
#    'patterns': ['nausea', 'nauseous', 'like vomit', 'feel sick']},
#   {'tag': 'neck_pain',
#    'patterns': ['neck hurts', 'pain in neck', 'neck stiff']},
#   {'tag': 'nodal_skin_eruptions',
#    'patterns': ['really bad rash', 'Swollen rash', 'bad skin']},
#   {'tag': 'obesity', 'patterns': ['high body weight', 'really fat', 'obese']},
#   {'tag': 'pain_behind_the_eyes',
#    'patterns': ['eyes hurt', 'Back of eyes hurt', 'hurts behind eyes']},
#   {'tag': 'pain_during_bowel_movements',
#    'patterns': ['hurts when go toilet', 'Pooping hurts', 'pain when pooping']},
#   {'tag': 'pain_in_anal_region',
#    'patterns': ['anus hurts', 'butt hurts', 'pain anal region', 'pain anus']},
#   {'tag': 'painful_walking',
#    'patterns': ["can't walk",
#     'hurts when walk',
#     'Walking hurts',
#     'Walking painful']},
#   {'tag': 'palpitations',
#    'patterns': ['palpitations',
#     'heart skipped beat',
#     'Heart extra beats',
#     'heart racing',
#     'Heart pounding']},
#   {'tag': 'passage_of_gases', 'patterns': ['burp', 'fart', 'gassy']},
#   {'tag': 'patches_in_throat',
#    'patterns': ['patchy throat',
#     'tonsils hurt',
#     'throat hurts',
#     'Patches throat']},
#   {'tag': 'phlegm',
#    'patterns': ['phlegm',
#     'phlegm bad',
#     'cough lot of phlegm',
#     'coughing up mucus']},
#   {'tag': 'polyuria',
#    'patterns': ['pee a lot', 'Pee lot of liquid', 'lot of urine']},
#   {'tag': 'prominent_veins_on_calf',
#    'patterns': ['legs show veins',
#     'Veins on legs prominent',
#     'Veins showing',
#     'Veins on legs emphasized']},
#   {'tag': 'puffy_face_and_eyes',
#    'patterns': ['puffy face and eyes', 'puffy face', 'Eyes puffy']},
#   {'tag': 'pus_filled_pimples',
#    'patterns': ['pus filled pimples',
#     'acne',
#     'pimples with pus',
#     'bad pimples',
#     'Yellow pus pimples']},
#   {'tag': 'receiving_blood_transfusion',
#    'patterns': ['need blood transfusion',
#     'got transfusion',
#     'receiving blood transfusion']},
#   {'tag': 'receiving_unsterile_injections',
#    'patterns': ['unsterile injection',
#     'weird injection',
#     'injected shady needle']},
#   {'tag': 'red_sore_around_nose',
#    'patterns': ['red sore around nose',
#     'rash around nose',
#     'red bumps nose',
#     'nose sore red']},
#   {'tag': 'yellowish_skin',
#    'patterns': ['yellowish skin',
#     'skin turned yellow',
#     'Jaundice',
#     'yellow color skin',
#     'yellowish pigmentation',
#     'greenish pigmentation']},
#   {'tag': 'yellowing_of_eyes',
#    'patterns': ['yellowing of eyes',
#     'eyes turned yellow',
#     'Jaundice',
#     'Whites of eyes yellow',
#     'yellowing eyes']},
#   {'tag': 'yellow_urine',
#    'patterns': ['urine yellow',
#     'urine bright yellow',
#     'urine dark yellow',
#     'color of urine deep yellow']},
#   {'tag': 'yellow_crust_ooze',
#    'patterns': ['yellow crust ooze',
#     'yellowish crust',
#     'Yellow fluid oozed scab',
#     'Yellow liquid from scab',
#     'Oozy scabs']},
#   {'tag': 'weight_loss',
#    'patterns': ['weight loss',
#     'lost lot of weight',
#     'getting thinner',
#     'skinnier',
#     'lost weight unintentionally']},
#   {'tag': 'weight_gain',
#    'patterns': ['weight gain',
#     'gained lot of weight',
#     'getting fatter without eating',
#     'gained weight significantly']},
#   {'tag': 'weakness_of_one_body_side',
#    'patterns': ['weakness on one part of body',
#     'left side weaker than right side',
#     'right side weaker than left side',
#     'Hemiparesis',
#     'partial weakness']},
#   {'tag': 'weakness_in_limbs',
#    'patterns': ['weakness in limbs',
#     'limbs weak',
#     'leg weakness',
#     'arm weakness',
#     'weakness in arms and hands']},
#   {'tag': 'watering_from_eyes',
#    'patterns': ['watering eyes',
#     'teary eyes',
#     'excessive tearing',
#     'watering from eyes']},
#   {'tag': 'vomiting',
#    'patterns': ['had vomited',
#     'vomiting',
#     'threw up',
#     'puked',
#     'puking',
#     'throwing up']},
#   {'tag': 'visual_disturbances',
#    'patterns': ['visual disturbances',
#     'flashing before eyes',
#     'double vision',
#     'brief attacks of blindness',
#     "can't see clearly"]},
#   {'tag': 'unsteadiness',
#    'patterns': ['unsteadiness',
#     'fell lost balance',
#     'like going to fall',
#     'unsteady',
#     'imbalanced']},
#   {'tag': 'ulcers_on_tongue',
#    'patterns': ['ulcers on tongue',
#     'tongue ulcers',
#     'tongue is sore',
#     'ulcers in mouth',
#     'mouth ulcers']},
#   {'tag': 'toxic_look_(typhos)',
#    'patterns': ['toxic look typhos', "don't look so good"]},
#   {'tag': 'throat_irritation',
#    'patterns': ['throat irritation',
#     'throat feels sore',
#     'sore throat',
#     'throat is irritated',
#     'scratchiness in throat']},
#   {'tag': 'swollen_legs',
#    'patterns': ['swollen legs',
#     'legs swollen',
#     'feet swollen',
#     'legs feet swelling']},
#   {'tag': 'swollen_extremeties',
#    'patterns': ['swollen extremeties',
#     'swollen legs',
#     'swollen arms',
#     'feet swollen',
#     'hands swollen',
#     'swelling legs',
#     'swelling arms',
#     'feet swelling',
#     'hands swelling']},
#   {'tag': 'swollen_blood_vessels',
#    'patterns': ['blood vessels swollen', 'blood vessels thicker']},
#   {'tag': 'swelling_of_stomach',
#    'patterns': ['stomach swolen',
#     'swelling of stomach',
#     'abdomen swollen',
#     'swelling of abdomen']},
#   {'tag': 'swelling_joints',
#    'patterns': ['joints swollen',
#     'swelling in joints',
#     'ankles swollen',
#     'ankles swelling',
#     'wrists swollen',
#     'wrists swelling']},
#   {'tag': 'swelled_lymph_nodes',
#    'patterns': ['lymph nodes swollen',
#     'swelling in lymph nodes',
#     'lymph nodes bigger',
#     'swollen lymph glands']},
#   {'tag': 'sweating',
#    'patterns': ['sweating',
#     'sweating too much',
#     'sweating a lot',
#     'sweating excessively']},
#   {'tag': 'sunken_eyes',
#    'patterns': ['sunken eyes',
#     'eyes tired',
#     'dark circles under eyes',
#     'skin around eyes dark',
#     'skin around eyes thinner',
#     'bags under eyes']},
#   {'tag': 'stomach_pain',
#    'patterns': ['stomach hurts',
#     'stomach pain',
#     'abdomen pain',
#     'abdomen hurts']},
#   {'tag': 'stomach_bleeding',
#    'patterns': ['stomach bleeds', 'bleeding in stomach']},
#   {'tag': 'stiff_neck',
#    'patterns': ['neck hurts', 'stiff neck', 'neck pain', 'neck stiffness']},
#   {'tag': 'spotting_urination',
#    'patterns': ['spotting urination',
#     'spotted blood urine',
#     'little blood urine']},
#   {'tag': 'spinning_movements',
#    'patterns': ['spinning movements', 'like spinning', 'like moving']},
#   {'tag': 'small_dents_in_nails',
#    'patterns': ['dents in nails',
#     'nail pitting',
#     'nail pits',
#     'nails different']},
#   {'tag': 'slurred_speech',
#    'patterns': ['slurred speech',
#     'speech problems',
#     "can't pronounce words",
#     'mumbling',
#     'difficulty speaking',
#     "don't understand when speaking"]},
#   {'tag': 'skin_rash',
#    'patterns': ['rash',
#     'lesions on skin',
#     'skin red and itchy',
#     'skin rash',
#     'skin dry']},
#   {'tag': 'skin_peeling', 'patterns': ['skin peeling']},
#   {'tag': 'sinus_pressure',
#    'patterns': ['pressure in sinuses',
#     'sinus pressure',
#     'pain in sinuses',
#     'sinuses congested',
#     'pain in forehead',
#     'pain between eyes']},
#   {'tag': 'silver_like_dusting',
#    'patterns': ['silver like dusting', 'skin blue', 'skin grey']},
#   {'tag': 'shivering', 'patterns': ['shivering', 'chills']},
#   {'tag': 'scurring', 'patterns': ['scurring']},
#   {'tag': 'rusty_sputum',
#    'patterns': ['rusty sputum',
#     'brown phlegm',
#     'rusty brown sputum',
#     'brown sputum']},
#   {'tag': 'runny_nose',
#    'patterns': ['runny nose',
#     'watery runny nose',
#     'watery secretion from nose',
#     'Fluid from nose']},
#   {'tag': 'restlessness',
#    'patterns': ['restlessness',
#     'need to move around',
#     'inner tension',
#     "can't calm mind",
#     'cramps in extremities',
#     'urge to move']},
#   {'tag': 'redness_of_eyes',
#    'patterns': ['redness of eyes',
#     'red eyes',
#     'eyes are red',
#     'eyes are dry']},
#   {'tag': 'red_spots_over_body',
#    'patterns': ['red spots over body',
#     'red spots on body',
#     'small patches on body']}]}

# %%
import pandas as pd
import nltk
import numpy as np
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('stopwords')


lemmatizer = WordNetLemmatizer()
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
from spacy.lang.en.stop_words import STOP_WORDS
import spacy
nlp = spacy.load('en_core_web_sm')

# %%
def preprocess(doc):
    doc=doc.replace("'t",' not')
    nlp_doc=nlp(doc)
    d=[]
    for token in nlp_doc:
        if(not token.text.lower()  in STOP_WORDS and  token.text.isalpha()):
            d.append(token.lemma_.lower() )
    return ' '.join(d)

# %%
stp=stopwords.words('english')
stp.remove('not')

# %%
## tiền xử lý một câu trong quá trình xử lý ngôn ngữ tự nhiên (NLP)

def preprocess_sent(sent):
    sent=sent.replace("'t",' not')
    t=nltk.word_tokenize(sent) ## câu được chia thành các từ riêng lẻ (còn được gọi là "tokens")
    return ' '.join([lemmatizer.lemmatize(w.lower()) for w in t if (w not in stp and w.isalpha())])

# %%
preprocess_sent("i have sneezing and coughing. Sometime, I have a headache")
# Out:
# 'sneezing coughing sometime i headache'

# %%
sent=[]
app_tag=[]  ## tag của câu
for intent in intents['intents']:
    tag = intent['tag']
    for pattern in intent['patterns']:
        sent.append(preprocess_sent(pattern))
        app_tag.append(tag)

# %%
sent    #Danh sách các triệu chứng đã được tiền xử lý (vd:  'pain in stomach' -> 'pain stomach')
app_tag #Danh sách các tag tương ứng với các triệu chứng
# Out:
# ['abdominal_pain',
#  'abdominal_pain',
#  'abdominal_pain',
#  'abdominal_pain',
#  'anxiety',
#  'abnormal_menstruation',
#  'abnormal_menstruation',
#  'abnormal_menstruation',
#  'abnormal_menstruation',
#  'abnormal_menstruation',
#  'abnormal_menstruation',
#  'abnormal_menstruation',
#  'acidity',
#  'acidity',
#  'acidity',
#  'acute_liver_failure',
#  'acute_liver_failure',
#  'acute_liver_failure',
#  'acute_liver_failure',
#  'altered_sensorium',
#  'altered_sensorium',
#  'altered_sensorium',
#  'altered_sensorium',
#  'anxiety',
#  'anxiety',
#  'anxiety',
#  'anxiety',
#  'back_pain',
#  'back_pain',
#  'back_pain',
#  'belly_pain',
#  'belly_pain',
#  'belly_pain',
#  'belly_pain',
#  'belly_pain',
#  'blackheads',
#  'blackheads',
#  'blackheads',
#  'blackheads',
#  'bladder_discomfort',
#  'bladder_discomfort',
#  'bladder_discomfort',
#  'bladder_discomfort',
#  'blister',
#  'blister',
#  'blister',
#  'blister',
#  'blood_in_sputum',
#  'blood_in_sputum',
#  'blood_in_sputum',
#  'bloody_stool',
#  'bloody_stool',
#  'bloody_stool',
#  'blurred_and_distorted_vision',
#  'blurred_and_distorted_vision',
#  'blurred_and_distorted_vision',
#  'blurred_and_distorted_vision',
#  'blurred_and_distorted_vision',
#  'breathlessness',
#  'breathlessness',
#  'breathlessness',
#  'breathlessness',
#  'breathlessness',
#  'brittle_nails',
#  'brittle_nails',
#  'brittle_nails',
#  'brittle_nails',
#  'bruising',
#  'bruising',
#  'bruising',
#  'bruising',
#  'burning_micturition',
#  'burning_micturition',
#  'burning_micturition',
#  'burning_micturition',
#  'chest_pain',
#  'chest_pain',
#  'chest_pain',
#  'chills',
#  'chills',
#  'cold_hands_and_feets',
#  'cold_hands_and_feets',
#  'cold_hands_and_feets',
#  'cold_hands_and_feets',
#  'cold_hands_and_feets',
#  'coma',
#  'coma',
#  'coma',
#  'constipation',
#  'constipation',
#  'constipation',
#  'constipation',
#  'continuous_feel_of_urine',
#  'continuous_feel_of_urine',
#  'continuous_feel_of_urine',
#  'continuous_feel_of_urine',
#  'continuous_sneezing',
#  'continuous_sneezing',
#  'continuous_sneezing',
#  'continuous_sneezing',
#  'continuous_sneezing',
#  'cough',
#  'cough',
#  'cough',
#  'cough',
#  'cough',
#  'congestion',
#  'congestion',
#  'congestion',
#  'congestion',
#  'congestion',
#  'cramps',
#  'cramps',
#  'dark_urine',
#  'dark_urine',
#  'dark_urine',
#  'dehydration',
#  'dehydration',
#  'depression',
#  'depression',
#  'depression',
#  'diarrhoea',
#  'diarrhoea',
#  'diarrhoea',
#  'diarrhoea',
#  'dischromic_patches',
#  'dischromic_patches',
#  'dischromic_patches',
#  'dischromic_patches',
#  'distention_of_abdomen',
#  'distention_of_abdomen',
#  'distention_of_abdomen',
#  'distention_of_abdomen',
#  'dizziness',
#  'dizziness',
#  'dizziness',
#  'dizziness',
#  'dizziness',
#  'dizziness',
#  'drying_and_tingling_lips',
#  'drying_and_tingling_lips',
#  'drying_and_tingling_lips',
#  'drying_and_tingling_lips',
#  'drying_and_tingling_lips',
#  'enlarged_thyroid',
#  'enlarged_thyroid',
#  'excessive_hunger',
#  'excessive_hunger',
#  'excessive_hunger',
#  'excessive_hunger',
#  'extra_marital_contacts',
#  'extra_marital_contacts',
#  'extra_marital_contacts',
#  'family_history',
#  'family_history',
#  'family_history',
#  'family_history',
#  'family_history',
#  'fast_heart_rate',
#  'fast_heart_rate',
#  'fast_heart_rate',
#  'fast_heart_rate',
#  'fatigue',
#  'fatigue',
#  'fatigue',
#  'fatigue',
#  'fluid_overload',
#  'fluid_overload',
#  'fluid_overload',
#  'fluid_overload',
#  'foul_smell_ofurine',
#  'foul_smell_ofurine',
#  'foul_smell_ofurine',
#  'foul_smell_ofurine',
#  'headache',
#  'headache',
#  'headache',
#  'headache',
#  'high_fever',
#  'high_fever',
#  'high_fever',
#  'hip_joint_pain',
#  'hip_joint_pain',
#  'hip_joint_pain',
#  'history_of_alcohol_consumption',
#  'history_of_alcohol_consumption',
#  'history_of_alcohol_consumption',
#  'history_of_alcohol_consumption',
#  'increased_appetite',
#  'increased_appetite',
#  'increased_appetite',
#  'indigestion',
#  'indigestion',
#  'indigestion',
#  'indigestion',
#  'inflammatory_nails',
#  'inflammatory_nails',
#  'inflammatory_nails',
#  'inflammatory_nails',
#  'internal_itching',
#  'internal_itching',
#  'internal_itching',
#  'irregular_sugar_level',
#  'irregular_sugar_level',
#  'irregular_sugar_level',
#  'irregular_sugar_level',
#  'irregular_sugar_level',
#  'irritability',
#  'irritability',
#  'irritability',
#  'irritability',
#  'irritation_in_anus',
#  'irritation_in_anus',
#  'irritation_in_anus',
#  'irritation_in_anus',
#  'itching',
#  'itching',
#  'itching',
#  'joint_pain',
#  'joint_pain',
#  'joint_pain',
#  'joint_pain',
#  'knee_pain',
#  'knee_pain',
#  'lack_of_concentration',
#  'lack_of_concentration',
#  'lack_of_concentration',
#  'lack_of_concentration',
#  'lethargy',
#  'lethargy',
#  'lethargy',
#  'lethargy',
#  'lethargy',
#  'loss_of_appetite',
#  'loss_of_appetite',
#  'loss_of_appetite',
#  'loss_of_appetite',
#  'loss_of_balance',
#  'loss_of_balance',
#  'loss_of_balance',
#  'loss_of_balance',
#  'loss_of_balance',
#  'loss_of_smell',
#  'loss_of_smell',
#  'loss_of_smell',
#  'loss_of_smell',
#  'malaise',
#  'malaise',
#  'malaise',
#  'malaise',
#  'mild_fever',
#  'mild_fever',
#  'mild_fever',
#  'mild_fever',
#  'mood_swings',
#  'mood_swings',
#  'mood_swings',
#  'movement_stiffness',
#  'movement_stiffness',
#  'movement_stiffness',
#  'movement_stiffness',
#  'mucoid_sputum',
#  'mucoid_sputum',
#  'mucoid_sputum',
#  'muscle_pain',
#  'muscle_pain',
#  'muscle_pain',
#  'muscle_wasting',
#  'muscle_wasting',
#  'muscle_wasting',
#  'muscle_weakness',
#  'muscle_weakness',
#  'nausea',
#  'nausea',
#  'nausea',
#  'nausea',
#  'neck_pain',
#  'neck_pain',
#  'neck_pain',
#  'nodal_skin_eruptions',
#  'nodal_skin_eruptions',
#  'nodal_skin_eruptions',
#  'obesity',
#  'obesity',
#  'obesity',
#  'pain_behind_the_eyes',
#  'pain_behind_the_eyes',
#  'pain_behind_the_eyes',
#  'pain_during_bowel_movements',
#  'pain_during_bowel_movements',
#  'pain_during_bowel_movements',
#  'pain_in_anal_region',
#  'pain_in_anal_region',
#  'pain_in_anal_region',
#  'pain_in_anal_region',
#  'painful_walking',
#  'painful_walking',
#  'painful_walking',
#  'painful_walking',
#  'palpitations',
#  'palpitations',
#  'palpitations',
#  'palpitations',
#  'palpitations',
#  'passage_of_gases',
#  'passage_of_gases',
#  'passage_of_gases',
#  'patches_in_throat',
#  'patches_in_throat',
#  'patches_in_throat',
#  'patches_in_throat',
#  'phlegm',
#  'phlegm',
#  'phlegm',
#  'phlegm',
#  'polyuria',
#  'polyuria',
#  'polyuria',
#  'prominent_veins_on_calf',
#  'prominent_veins_on_calf',
#  'prominent_veins_on_calf',
#  'prominent_veins_on_calf',
#  'puffy_face_and_eyes',
#  'puffy_face_and_eyes',
#  'puffy_face_and_eyes',
#  'pus_filled_pimples',
#  'pus_filled_pimples',
#  'pus_filled_pimples',
#  'pus_filled_pimples',
#  'pus_filled_pimples',
#  'receiving_blood_transfusion',
#  'receiving_blood_transfusion',
#  'receiving_blood_transfusion',
#  'receiving_unsterile_injections',
#  'receiving_unsterile_injections',
#  'receiving_unsterile_injections',
#  'red_sore_around_nose',
#  'red_sore_around_nose',
#  'red_sore_around_nose',
#  'red_sore_around_nose',
#  'yellowish_skin',
#  'yellowish_skin',
#  'yellowish_skin',
#  'yellowish_skin',
#  'yellowish_skin',
#  'yellowish_skin',
#  'yellowing_of_eyes',
#  'yellowing_of_eyes',
#  'yellowing_of_eyes',
#  'yellowing_of_eyes',
#  'yellowing_of_eyes',
#  'yellow_urine',
#  'yellow_urine',
#  'yellow_urine',
#  'yellow_urine',
#  'yellow_crust_ooze',
#  'yellow_crust_ooze',
#  'yellow_crust_ooze',
#  'yellow_crust_ooze',
#  'yellow_crust_ooze',
#  'weight_loss',
#  'weight_loss',
#  'weight_loss',
#  'weight_loss',
#  'weight_loss',
#  'weight_gain',
#  'weight_gain',
#  'weight_gain',
#  'weight_gain',
#  'weakness_of_one_body_side',
#  'weakness_of_one_body_side',
#  'weakness_of_one_body_side',
#  'weakness_of_one_body_side',
#  'weakness_of_one_body_side',
#  'weakness_in_limbs',
#  'weakness_in_limbs',
#  'weakness_in_limbs',
#  'weakness_in_limbs',
#  'weakness_in_limbs',
#  'watering_from_eyes',
#  'watering_from_eyes',
#  'watering_from_eyes',
#  'watering_from_eyes',
#  'vomiting',
#  'vomiting',
#  'vomiting',
#  'vomiting',
#  'vomiting',
#  'vomiting',
#  'visual_disturbances',
#  'visual_disturbances',
#  'visual_disturbances',
#  'visual_disturbances',
#  'visual_disturbances',
#  'unsteadiness',
#  'unsteadiness',
#  'unsteadiness',
#  'unsteadiness',
#  'unsteadiness',
#  'ulcers_on_tongue',
#  'ulcers_on_tongue',
#  'ulcers_on_tongue',
#  'ulcers_on_tongue',
#  'ulcers_on_tongue',
#  'toxic_look_(typhos)',
#  'toxic_look_(typhos)',
#  'throat_irritation',
#  'throat_irritation',
#  'throat_irritation',
#  'throat_irritation',
#  'throat_irritation',
#  'swollen_legs',
#  'swollen_legs',
#  'swollen_legs',
#  'swollen_legs',
#  'swollen_extremeties',
#  'swollen_extremeties',
#  'swollen_extremeties',
#  'swollen_extremeties',
#  'swollen_extremeties',
#  'swollen_extremeties',
#  'swollen_extremeties',
#  'swollen_extremeties',
#  'swollen_extremeties',
#  'swollen_blood_vessels',
#  'swollen_blood_vessels',
#  'swelling_of_stomach',
#  'swelling_of_stomach',
#  'swelling_of_stomach',
#  'swelling_of_stomach',
#  'swelling_joints',
#  'swelling_joints',
#  'swelling_joints',
#  'swelling_joints',
#  'swelling_joints',
#  'swelling_joints',
#  'swelled_lymph_nodes',
#  'swelled_lymph_nodes',
#  'swelled_lymph_nodes',
#  'swelled_lymph_nodes',
#  'sweating',
#  'sweating',
#  'sweating',
#  'sweating',
#  'sunken_eyes',
#  'sunken_eyes',
#  'sunken_eyes',
#  'sunken_eyes',
#  'sunken_eyes',
#  'sunken_eyes',
#  'stomach_pain',
#  'stomach_pain',
#  'stomach_pain',
#  'stomach_pain',
#  'stomach_bleeding',
#  'stomach_bleeding',
#  'stiff_neck',
#  'stiff_neck',
#  'stiff_neck',
#  'stiff_neck',
#  'spotting_urination',
#  'spotting_urination',
#  'spotting_urination',
#  'spinning_movements',
#  'spinning_movements',
#  'spinning_movements',
#  'small_dents_in_nails',
#  'small_dents_in_nails',
#  'small_dents_in_nails',
#  'small_dents_in_nails',
#  'slurred_speech',
#  'slurred_speech',
#  'slurred_speech',
#  'slurred_speech',
#  'slurred_speech',
#  'slurred_speech',
#  'skin_rash',
#  'skin_rash',
#  'skin_rash',
#  'skin_rash',
#  'skin_rash',
#  'skin_peeling',
#  'sinus_pressure',
#  'sinus_pressure',
#  'sinus_pressure',
#  'sinus_pressure',
#  'sinus_pressure',
#  'sinus_pressure',
#  'silver_like_dusting',
#  'silver_like_dusting',
#  'silver_like_dusting',
#  'shivering',
#  'shivering',
#  'scurring',
#  'rusty_sputum',
#  'rusty_sputum',
#  'rusty_sputum',
#  'rusty_sputum',
#  'runny_nose',
#  'runny_nose',
#  'runny_nose',
#  'runny_nose',
#  'restlessness',
#  'restlessness',
#  'restlessness',
#  'restlessness',
#  'restlessness',
#  'restlessness',
#  'redness_of_eyes',
#  'redness_of_eyes',
#  'redness_of_eyes',
#  'redness_of_eyes',
#  'red_spots_over_body',
#  'red_spots_over_body',
#  'red_spots_over_body']

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 1.5.0

# %%
vectorizer = TfidfVectorizer()
vectors = vectorizer.fit_transform(sent)
feature_names = vectorizer.get_feature_names_out()
dense = vectors.todense()
denselist = dense.tolist()
df = pd.DataFrame(denselist, columns=feature_names)

# %%
vocab=list(df.columns)
vocab
# Out:
# ['abdomen',
#  'abdominal',
#  'abnormal',
#  'ache',
#  'acid',
#  'acidity',
#  'acne',
#  'acute',
#  'affair',
#  'alcohol',
#  'also',
#  'altered',
#  'always',
#  'anal',
#  'ankle',
#  'annoyed',
#  'anus',
#  'anxeity',
#  'anxiety',
#  'anxious',
#  'anything',
#  'appetite',
#  'arm',
#  'around',
#  'atrophy',
#  'attack',
#  'back',
#  'bad',
#  'bag',
#  'balance',
#  'beat',
#  'beating',
#  'behind',
#  'belly',
#  'bigger',
#  'blackhead',
#  'bladder',
#  'bleeding',
#  'bleeds',
#  'blindness',
#  'blister',
#  'blistered',
#  'bloated',
#  'blood',
#  'bloody',
#  'blue',
#  'blurred',
#  'blurry',
#  'body',
#  'breath',
#  'breathe',
#  'breathing',
#  'breathlessness',
#  'brief',
#  'bright',
#  'brittle',
#  'broken',
#  'brown',
#  'bruise',
#  'bruised',
#  'bruising',
#  'bump',
#  'burn',
#  'burning',
#  'burp',
#  'butt',
#  'calm',
#  'can',
#  'caughing',
#  'change',
#  'chest',
#  'chill',
#  'circle',
#  'clearly',
#  'cold',
#  'color',
#  'coma',
#  'comfortable',
#  'concentrate',
#  'concentration',
#  'congested',
#  'congestion',
#  'constantly',
#  'constipated',
#  'consumption',
#  'contact',
#  'continuous',
#  'cough',
#  'coughing',
#  'cramp',
#  'cramping',
#  'crust',
#  'dark',
#  'darker',
#  'deep',
#  'dehydrated',
#  'dehydration',
#  'dent',
#  'depressed',
#  'depression',
#  'diarrhoea',
#  'different',
#  'difficulty',
#  'dischromic',
#  'discomfort',
#  'disease',
#  'distention',
#  'distorted',
#  'disturbance',
#  'dizziness',
#  'dizzy',
#  'double',
#  'dried',
#  'drink',
#  'drinking',
#  'dry',
#  'drying',
#  'dusting',
#  'easily',
#  'eat',
#  'eating',
#  'emphasized',
#  'energy',
#  'enlarged',
#  'enthusiasm',
#  'everything',
#  'everywhere',
#  'excessive',
#  'excessively',
#  'expanded',
#  'experienced',
#  'experiencing',
#  'extra',
#  'extremeties',
#  'extremity',
#  'eye',
#  'face',
#  'failure',
#  'fall',
#  'family',
#  'fart',
#  'fast',
#  'fat',
#  'fatigued',
#  'fatter',
#  'feel',
#  'feeling',
#  'feets',
#  'fell',
#  'fever',
#  'fevered',
#  'filled',
#  'flashing',
#  'flow',
#  'fluid',
#  'focus',
#  'foot',
#  'forehead',
#  'foul',
#  'frustrated',
#  'full',
#  'gain',
#  'gained',
#  'gassy',
#  'genetically',
#  'genetics',
#  'getting',
#  'gland',
#  'go',
#  'going',
#  'good',
#  'got',
#  'greenish',
#  'grey',
#  'hand',
#  'hard',
#  'head',
#  'headache',
#  'heart',
#  'heartburn',
#  'heavy',
#  'hemiparesis',
#  'high',
#  'highered',
#  'hip',
#  'history',
#  'hunger',
#  'hungry',
#  'hurt',
#  'imbalanced',
#  'increased',
#  'indigestion',
#  'infected',
#  'inflamed',
#  'inflammation',
#  'inflammatory',
#  'injected',
#  'injection',
#  'inner',
#  'inside',
#  'internal',
#  'irregular',
#  'irritability',
#  'irritable',
#  'irritated',
#  'irritation',
#  'itch',
#  'itching',
#  'itchy',
#  'jaundice',
#  'joint',
#  'knee',
#  'lack',
#  'large',
#  'last',
#  'left',
#  'leg',
#  'lesion',
#  'lethargy',
#  'level',
#  'like',
#  'limb',
#  'lip',
#  'liquid',
#  'little',
#  'liver',
#  'long',
#  'longer',
#  'look',
#  'loosing',
#  'losing',
#  'loss',
#  'lost',
#  'lot',
#  'low',
#  'lymph',
#  'marital',
#  'menstrual',
#  'menstruation',
#  'micturition',
#  'mind',
#  'mood',
#  'mouth',
#  'move',
#  'movement',
#  'moving',
#  'much',
#  'mucous',
#  'mucus',
#  'mumbling',
#  'muscle',
#  'nail',
#  'nasal',
#  'nausea',
#  'nauseous',
#  'neck',
#  'need',
#  'needle',
#  'nervous',
#  'node',
#  'normal',
#  'normally',
#  'nose',
#  'not',
#  'obese',
#  'often',
#  'ofurine',
#  'one',
#  'ooze',
#  'oozed',
#  'oozy',
#  'overload',
#  'pain',
#  'painful',
#  'palpitation',
#  'parent',
#  'part',
#  'partial',
#  'patch',
#  'patched',
#  'patchy',
#  'pee',
#  'peeing',
#  'peeling',
#  'period',
#  'phlegm',
#  'pigmentation',
#  'pimple',
#  'pit',
#  'pitting',
#  'poo',
#  'poop',
#  'pooped',
#  'pooping',
#  'pounding',
#  'pressure',
#  'problem',
#  'prominent',
#  'pronounce',
#  'pu',
#  'puffy',
#  'puked',
#  'puking',
#  'pumping',
#  'racing',
#  'rash',
#  'rate',
#  'really',
#  'receiving',
#  'red',
#  'redness',
#  'reflux',
#  'region',
#  'restlessness',
#  'right',
#  'risk',
#  'runny',
#  'rusty',
#  'scab',
#  'scratchiness',
#  'scurring',
#  'secretion',
#  'see',
#  'sensation',
#  'sense',
#  'sensorium',
#  'sex',
#  'shady',
#  'shivering',
#  'short',
#  'show',
#  'showing',
#  'sick',
#  'side',
#  'significantly',
#  'silver',
#  'sinus',
#  'skin',
#  'skinnier',
#  'skipped',
#  'sleepy',
#  'slow',
#  'sluggy',
#  'slurred',
#  'small',
#  'smaller',
#  'smell',
#  'sneeze',
#  'sneezing',
#  'sore',
#  'speaking',
#  'speech',
#  'spinning',
#  'spot',
#  'spotted',
#  'spotting',
#  'sputum',
#  'stiff',
#  'stiffly',
#  'stiffness',
#  'stink',
#  'stomach',
#  'stool',
#  'stranger',
#  'strong',
#  'stuffy',
#  'suffer',
#  'sugar',
#  'sunken',
#  'sweating',
#  'swelling',
#  'swing',
#  'swolen',
#  'swollen',
#  'tearing',
#  'teary',
#  'temperature',
#  'tension',
#  'thicker',
#  'think',
#  'thinner',
#  'threw',
#  'throat',
#  'throwing',
#  'thyroid',
#  'time',
#  'tingling',
#  'tingly',
#  'tired',
#  'toilet',
#  'tongue',
#  'tonsil',
#  'toxic',
#  'transfusion',
#  'turned',
#  'typhos',
#  'ulcer',
#  'unable',
#  'understand',
#  'unintentionally',
#  'unsteadiness',
#  'unsteady',
#  'unsterile',
#  'upper',
#  'upset',
#  'urge',
#  'urination',
#  'urine',
#  'vein',
#  'vertigo',
#  'vessel',
#  'vision',
#  'visual',
#  'vomit',
#  'vomited',
#  'vomiting',
#  'walk',
#  'walking',
#  'want',
#  'watering',
#  'watery',
#  'weak',
#  'weaker',
#  'weakness',
#  'weight',
#  'weird',
#  'well',
#  'white',
#  'winded',
#  'without',
#  'woozy',
#  'word',
#  'worried',
#  'wrist',
#  'yellow',
#  'yellowing',
#  'yellowish']

# %%
def bag_of_words(tokenized_sentence, all_words):
    bag = np.zeros(len(all_words), dtype=np.float32)
    for idx, w in enumerate(all_words):
        if w in tokenized_sentence:
            bag[idx] = 1.0
    return bag

# %% [markdown]
# TEST

# %%
# synthetic dataset created for neural network validation
xy_test = [
    (['can',"'t", 'think', 'straight'], 'altered_sensorium'),
    (['suffer', 'from', 'anxeity'], 'anxiety'),
    (['suffer', 'from', 'anxeity'], 'anxiety'),
    (['bloody', 'poop'], 'bloody_stool'),
    (['blurred', 'vision'], 'blurred_and_distorted_vision'),
    (['can', "'t", 'breathe'], 'breathlessness'),
    (['Yellow', 'liquid', 'pimple'], 'yellow_crust_ooze'),
    (['lost', 'weight'], 'weight_loss'),
    (['side', 'weaker'], 'weakness_of_one_body_side'),
    (['watering', 'eyes'], 'watering_from_eyes'),
    (['brief', 'blindness'], 'visual_disturbances'),
    (['throat', 'hurts'], 'throat_irritation'),
    (['extremities', 'swelling'], 'swollen_extremeties'),
    (['swollen', 'lymph', 'nodes'], 'swelled_lymph_nodes'),
    (['dark', 'under', 'eyes'], 'sunken_eyes'),
    (['stomach', 'blood'], 'stomach_bleeding'),
    (['blood', 'urine'], 'spotting_urination'),
    (['sinuses', 'hurt'], 'sinus_pressure'),
    (['watery', 'from', 'nose'], 'runny_nose'),
    (['have', 'to', 'move'], 'restlessness'),
    (['red', 'patches', 'body'], 'red_spots_over_body'),
    (['sneeze'], 'continuous_sneezing'),
    (['coughing'], 'cough'),
    (['skin', 'patches'], 'dischromic_patches'),
    (['skin', 'bruised'], 'bruising'),
    (['burning', 'pee'], 'burning_micturition'),
    (['hurts', 'pee'], 'burning_micturition'),
    (['Burning', 'sensation'], 'burning_micturition'),
    (['chest', 'pressure'], 'chest_pain'),
    (['pain', 'butt'], 'pain_in_anal_region'),
    (['heart', 'bad', 'beat'], 'palpitations'),
    (['fart', 'lot'], 'passage_of_gases'),
    (['cough', 'phlegm'], 'phlegm'),
    (['lot', 'urine'], 'polyuria'),
    (['Veins', 'bigger'], 'prominent_veins_on_calf'),
    (['Veins', 'emphasized'], 'prominent_veins_on_calf'),
    (['yellow', 'pimples'], 'pus_filled_pimples'),
    (['red', 'nose'], 'red_sore_around_nose'),
    (['skin', 'yellow'], 'yellowish_skin'),
    (['eyes', 'yellow'], 'yellowing_of_eyes'),
    (['large', 'thyroid'], 'enlarged_thyroid'),
    (['really', 'hunger'], 'excessive_hunger'),
    (['always', 'hungry'], 'excessive_hunger'),
]

# %%
#df.to_csv(r'tfidfsymptoms.csv', index = False)

# %%
def preprocess_test(sent):
    return [lemmatizer.lemmatize(w.lower()) for w in sent if (w not in set(stopwords.words('english')) and w.isalpha())]

# %%
preprocess_sent(' '.join(xy_test[0][0]))
# Out:
# 'not think straight'

# %%
y_true=[]
y_pred=[]
for x,y in xy_test:
    y_true.append(y)
    p=preprocess_sent(' '.join(x))
    print(p)
    bow=np.array(bag_of_words(p,vocab))
    #    bow=vectorizer.transform(p).toarray()
    res=cosine_similarity(bow.reshape((1, -1)), df).reshape(-1)
    y_pred.append(app_tag[np.argmax(res)])
# Out:
# not think straight
# suffer anxeity
# suffer anxeity
# bloody poop
# blurred vision
# not breathe
# yellow liquid pimple
# lost weight
# side weaker
# watering eye
# brief blindness
# throat hurt
# extremity swelling
# swollen lymph node
# dark eye
# stomach blood
# blood urine
# sinus hurt
# watery nose
# move
# red patch body
# sneeze
# coughing
# skin patch
# skin bruised
# burning pee
# hurt pee
# burning sensation
# chest pressure
# pain butt
# heart bad beat
# fart lot
# cough phlegm
# lot urine
# vein bigger
# vein emphasized
# yellow pimple
# red nose
# skin yellow
# eye yellow
# large thyroid
# really hunger
# always hungry

# %%
y_pred
# Out:
# ['altered_sensorium',
#  'anxiety',
#  'anxiety',
#  'constipation',
#  'blurred_and_distorted_vision',
#  'loss_of_appetite',
#  'yellow_crust_ooze',
#  'weight_loss',
#  'weakness_of_one_body_side',
#  'watering_from_eyes',
#  'visual_disturbances',
#  'patches_in_throat',
#  'restlessness',
#  'swelled_lymph_nodes',
#  'sunken_eyes',
#  'belly_pain',
#  'spotting_urination',
#  'sinus_pressure',
#  'runny_nose',
#  'restlessness',
#  'red_spots_over_body',
#  'continuous_sneezing',
#  'cough',
#  'patches_in_throat',
#  'bruising',
#  'burning_micturition',
#  'burning_micturition',
#  'burning_micturition',
#  'chest_pain',
#  'pain_in_anal_region',
#  'palpitations',
#  'passage_of_gases',
#  'phlegm',
#  'polyuria',
#  'prominent_veins_on_calf',
#  'prominent_veins_on_calf',
#  'pus_filled_pimples',
#  'red_sore_around_nose',
#  'yellowish_skin',
#  'yellowing_of_eyes',
#  'enlarged_thyroid',
#  'excessive_hunger',
#  'excessive_hunger']

# %%
error=0
for i in range(len(y_pred)):
    if y_pred[i]!=y_true[i]:
        error+=1

# %%
1-error/len(y_true)
# Out:
# 0.8604651162790697

# %%
x=['breathe']
p=preprocess_sent(' '.join(x))
bow=np.array(bag_of_words(p,vocab))
res=cosine_similarity(bow.reshape((1, -1)), df).reshape(-1)
app_tag[np.argmax(res)]
# Out:
# 'breathlessness'

# %%
a=np.argsort(res)[::-1][:2].tolist()

# %% [markdown]
# DEPLOYMENT

# %%
df=pd.read_csv('F:\PBL7\AI-Healthcare\\app\Data\\tfidfsymptoms.csv')
vocab=list(df.columns)

# %%
import joblib
knn = joblib.load('F:\PBL7\AI-Healthcare\\app\model\knn_sample.pkl')  
#knn_from_joblib.predict(X_test) 

# import joblib
# import pickle
# model_path = r'F:\\PBL7\AI-Healthcare\\app\\model\\xgboost_model.pkl'
# with open(model_path, 'rb') as file:
#         knn = pickle.load(file)
# #knn_from_joblib.predict(X_test)
# Out:
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:376: InconsistentVersionWarning: Trying to unpickle estimator KNeighborsClassifier from version 0.24.2 when using version 1.5.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
def bag_of_words(tokenized_sentence, all_words):
    bag = np.zeros(len(all_words), dtype=np.float32)
    for idx, w in enumerate(all_words):
        if w in tokenized_sentence:
            bag[idx] = 1.0
    return bag

# %%
def predictSym(sym,vocab,app_tag):
    sym=preprocess_sent(sym)
    print('test sym: ' + sym)
    bow=np.array(bag_of_words(sym,vocab))

    res=cosine_similarity(bow.reshape((1, -1)), df).reshape(-1)
    order=np.argsort(res)[::-1].tolist()
    possym=[]
    correctsym = []
    
    for i in order:
        if app_tag[i] not in correctsym:
            if app_tag[i].replace('_',' ') in sym:
                correctsym.append(app_tag[i])
            else :
                if app_tag[i] not in possym and res[i]!=0:
                    possym.append(app_tag[i])
    return correctsym, possym

# %%
test = 'I cough and sneeze a lot . Sometime, I have a headache'

correctsym, psym1 = predictSym(test,vocab,app_tag)
print("test correctsym : ")
print(correctsym)
print("test psym1 : ")
print(psym1)
# Out:
# test sym: i cough sneeze lot sometime i headache
# test correctsym :
# ['cough', 'headache']
# test psym1 :
# ['continuous_sneezing', 'phlegm', 'muscle_pain', 'polyuria', 'blackheads', 'sweating', 'bruising', 'diarrhoea', 'history_of_alcohol_consumption', 'weight_loss', 'weight_gain']

# %%
df_tr=pd.read_csv('F:\PBL7\AI-Healthcare\\app\Data\TrainingSample.csv')

# %%
#recoit client_symptoms et renvoit un dataframe avec 1 pour les symptoms associees
# def OHV(cl_sym,all_sym):
#     l=np.zeros([1,len(all_sym)])
#     for sym in cl_sym:
#         l[0,all_sym.index(sym)]=1
#     return pd.DataFrame(l, columns =all_symp)

def OHV(cl_sym, all_sym):
    l = np.zeros([1, len(all_sym)])
    for sym in cl_sym:
        if sym in all_sym:
            l[0, all_sym.index(sym)] = 1
    return pd.DataFrame(l, columns=all_sym)

def contains(small, big):
    a=True
    for i in small:
        if i not in big:
            a=False
    return a

def possible_diseases(l,disease):
    poss_dis=[]
    for dis in set(disease):
        if contains(l,symVONdisease(df_tr,dis)):
            poss_dis.append(dis)
    return poss_dis


#recoit une maladie renvoit tous les sympts
def symVONdisease(df,disease):
    ddf=df[df.prognosis==disease]
    m2 = (ddf == 1).any()
    return m2.index[m2].tolist()
    
def clean_symp(sym):
    return sym.replace('_',' ').replace('.1','').replace('(typhos)','').replace('yellowish','yellow').replace('yellowing','yellow')

# %%
disease = df_tr.iloc[:,-1].to_list()
all_symp_col=list(df_tr.columns[:-1])
all_symp=[clean_symp(sym) for sym in (all_symp_col)]
print(len(all_symp_col))

def possible_diseases(l):
    poss_dis=[]
    for dis in set(disease):
        if contains(l,symVONdisease(df_tr,dis)):
            poss_dis.append(dis)
    return poss_dis
# Out:
# 132

# %%
symVONdisease(df_tr,'Allergy')
# Out:
# ['continuous_sneezing', 'shivering', 'chills', 'watering_from_eyes']

# %%
test =['cough',  'continuous_sneezing', 'phlegm']
a= possible_diseases(test)
a
# Out:
# ['Common Cold']

# %%
import csv

severityDictionary=dict()
description_list = dict()
precautionDictionary=dict()

def getDescription():
    global description_list
    with open('F:\PBL7\AI-Healthcare\\app\Data\symptom_Description_Sample.csv') as csv_file:
        csv_reader = csv.reader(csv_file, delimiter=',')
        line_count = 0
        for row in csv_reader:
            _description={row[0]:row[1]}
            description_list.update(_description)




def getSeverityDict():
    global severityDictionary
    with open('F:\PBL7\AI-Healthcare\\app\Data\symptom_severity_Sample.csv') as csv_file:

        csv_reader = csv.reader(csv_file, delimiter=',')
        line_count = 0
        try:
            for row in csv_reader:
                _diction={row[0]:int(row[1])}
                severityDictionary.update(_diction)
        except:
            pass


def getprecautionDict():
    global precautionDictionary
    with open('F:\PBL7\AI-Healthcare\\app\Data\symptom_precaution_Sample.csv') as csv_file:

        csv_reader = csv.reader(csv_file, delimiter=',')
        line_count = 0
        for row in csv_reader:
            _prec={row[0]:[row[1],row[2],row[3],row[4]]}
            precautionDictionary.update(_prec)

def calc_condition(exp,days):
    sum=0
    for item in exp:
         sum=sum+severityDictionary[item]
    if((sum*days)/(len(exp))>13):
        return 1
        print("You should take the consultation from doctor. ")
    else:
        return 0
        print("It might not be that bad but you should take precautions.")

# %%
getSeverityDict()
getprecautionDict()
getDescription()

# %%
def main_sp(name, sym = None):
    #main Idea: At least two initial sympts to start with
    
    #get the 1st syp ->> process it ->> check_pattern ->>> get the appropriate one (if check_pattern==1 == similar syntaxic symp found)
    if sym is None:
        print("Hi Mr/Ms "+name+", can you describe you main symptom ?  \n\t\t\t\t\t\t",end="=>")
        sym1 = input("")
        sym = sym1     

    print("\ntest input : ", sym)
       
    correctsym1, psym1 = predictSym(sym,vocab,app_tag)
    print("test correctsym 1 : ")
    print(correctsym1)
    print("test psym1 : ")
    print(psym1)
    
    if len(psym1)==0 and len(correctsym1)==0:
        print("I am sorry, I am not able to understand your symptoms.")
        return None    
    
    print('Based on the signs you provided, I want to ask you a few things to confirm the information.')
    i=0
    while True and i<len(psym1):
        print('Do you experience '+psym1[i].replace('_',' ')+ ' ?')
        rep=input("")
        if str(rep)=='yes':
            correctsym1.append(psym1[i])
        i=i+1

    
    checkinput2nd = False
    print("Do you have any other symptoms?")
    sym2=input("")
    if(sym2 != "no"):
        checkinput2nd = True
        correctsym2, psym2 = predictSym(sym2,vocab,app_tag)
        i=0
        while True and i<len(psym2):
            print('Do you experience '+psym2[i].replace('_',' '))
            rep=input("")
            if str(rep)=='yes':
                correctsym2.append(psym2[i])
        i=i+1

    print("\n\nThank you for providing me with this information.\n")

    #create patient symp list
    # all_sym=[sym1,sym2]
    if checkinput2nd == False:
        all_sym=correctsym1
    else:
        all_sym=correctsym1 + correctsym2
    print("test lists all_sym : ")
    print(all_sym)
    #predict possible diseases
    diseases=possible_diseases(all_sym)
    print("test lists disease : ")
    print(diseases)

    if len(diseases) != 0:
        stop = False
        # print("Are you experiencing any ")
        for dis in diseases:
            if stop==False:
                for sym in symVONdisease(df_tr,dis):
                    if sym not in all_sym:
                        print("Are you experiencing any " + clean_symp(sym)+' ?')
                        while True:
                            inp=input("")
                            if(inp=="yes" or inp=="no"):
                                print("user input")
                                print(inp)
                                break
                            else:
                                print("provide proper answers i.e. (yes/no) : ",end="")
                                
                        if inp=="yes":
                            all_sym.append(sym)
                            print("TEST all_sym 2 : ")
                            print(all_sym)

                            dise=possible_diseases(all_sym)
                            print("TEST possible diseases : ")
                            print(dise)
                            if len(dise)==1:
                                stop=True 
                                break
                        else:
                            continue

    return knn.predict(OHV(all_sym,all_symp_col))

# %%
def chat_sp():
    a=True
    sym=None
    while a:
        result =main_sp('Thanh',sym)
        if result == None :
            print("Can you specify more what you feel or tap q to stop the conversation")
            ans3=input("")
            if ans3=="q":
                a=False
            else:
                sym = ans3
        else:
            print("result 2: ")
            print("you may have " + str(result[0]))
            print(description_list[result[0]])
            # an = input("how many day do you feel those symptoms ?")
            # if calc_condition(sym,int(an))==1:
            #     print("you should take the consultation from doctor")
            # else : 
            #     print('Take following precautions : ')
            #     for e in precautionDictionary[result[0]]:
            #         print(e)
            print("\n\nDo you need another medical consultation (yes or no)? ")
            ans=input()
            if ans!="yes":
                a=False
                print("!!!!! thanks for using ower application !!!!!! ")

# %%
chat_sp()
# Out:
# Hi Mr/Ms Thanh, can you describe you main symptom ?
# 						=>
# test input :  I have sneezing and coughing. Sometime, I have a headache
# test sym: i sneezing coughing sometime i headache
# test correctsym 1 :
# ['cough', 'headache']
# test psym1 :
# ['continuous_sneezing', 'muscle_pain', 'blood_in_sputum', 'phlegm', 'mucoid_sputum', 'history_of_alcohol_consumption']
# Based on the signs you provided, I want to ask you a few things to confirm the information.
# Do you experience continuous sneezing ?
# Do you experience muscle pain ?
# Do you experience blood in sputum ?
# Do you experience phlegm ?
# Do you experience mucoid sputum ?
# Do you experience history of alcohol consumption ?
# Do you have any other symptoms?
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but KNeighborsClassifier was fitted without feature names
#   warnings.warn(
# Thank you for providing me with this information.
#
# test lists all_sym :
# ['cough', 'headache', 'continuous_sneezing', 'muscle_pain', 'blood_in_sputum', 'phlegm']
# test lists disease :
# []
# result 2:
# you may have Allergy
# An allergy is an immune system response to a foreign substance that's not typically harmful to your body.They can include certain foods, pollen, or pet dander. Your immune system's job is to keep you healthy by fighting harmful pathogens.
#
#
# Do you need another medical consultation (yes or no)?
# !!!!! thanks for using ower application !!!!!!
